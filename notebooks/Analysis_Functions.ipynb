# %%
import pandas as pd

# %%
data = pd.read_csv('../data/processed/clean_rural_info.csv')

group_data = data.groupby(['Country','Job_name','Rural'], as_index=False).count()

    
group_data['Percentage'] = group_data['Quantity'].apply(lambda qtty: str((qtty*100/group_data['Quantity'].sum()).round(2))+'%')

group_data[group_data['Country']=='Austria']
# Out:
#     Country                                           Job_name  Rural  \
# 0   Austria  Automatic Data Processing Customer Liaison (AD...  rural
# 1   Austria  Automatic Data Processing Customer Liaison (AD...  urban
# 2   Austria                  Automatic Data Processing Planner  rural
# 3   Austria                  Automatic Data Processing Planner  urban
# 4   Austria  Automatic Data Processing Systems Security Spe...  rural
# ..      ...                                                ...    ...
# 56  Austria  Geographic Information Systems Database Admini...  urban
# 57  Austria                       Internet Database Specialist  rural
# 58  Austria                           Maintenance Data Analyst  urban
# 59  Austria  Naval Tactical Data System--Combat Information...  rural
# 60  Austria  Naval Tactical Data System--Combat Information...  urban
#
#     Quantity Percentage
# 0          1      0.02%
# 1          1      0.02%
# 2          1      0.02%
# 3          1      0.02%
# ...

# %%
group_data['Quantity'].sum()
# Out:
# 5702
