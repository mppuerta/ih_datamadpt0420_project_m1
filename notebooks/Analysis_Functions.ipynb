# %%
import pandas as pd

# %%
data = pd.read_csv('../data/processed/clean_rural_info.csv')

group_data = data.groupby(['Country','Job_name','Rural'], as_index=False).count()

    
group_data['Percentage'] = group_data['Quantity'].apply(lambda qtty: str((qtty*100/group_data['Quantity'].sum()).round(2))+'%')

group_data
# Out:
#                                                 Country  \
# 0                                               Austria
# 1                                               Austria
# 2                                               Austria
# 3                                               Austria
# 4                                               Austria
# ...                                                 ...
# 2403  United Kingdom of Great Britain and Northern I...
# 2404  United Kingdom of Great Britain and Northern I...
# 2405  United Kingdom of Great Britain and Northern I...
# 2406  United Kingdom of Great Britain and Northern I...
# 2407  United Kingdom of Great Britain and Northern I...
#
#                                                Job_name  Rural  Quantity  \
# 0     Automatic Data Processing Customer Liaison (AD...  rural         1
# 1     Automatic Data Processing Customer Liaison (AD...  urban         1
# 2                     Automatic Data Processing Planner  rural         1
# 3                     Automatic Data Processing Planner  urban         1
# 4     Automatic Data Processing Systems Security Spe...  rural         1
# ...                                                 ...    ...       ...
# 2403         Oracle Database Administrator (Oracle DBA)  urban         8
# 2404  SCADA Operator (Supervisory Control and Data A...  urban         1
# 2405  SCADA Technician (Supervisory Control and Data...  urban         1
# 2406                         SQL Database Administrator  urban         8
# 2407                             Survey Data Technician  urban         1
#
#      Percentage
# 0         0.02%
# 1         0.02%
# 2         0.02%
# 3         0.02%
# 4         0.02%
# ...         ...
# 2403      0.14%
# 2404      0.02%
# 2405      0.02%
# 2406      0.14%
# 2407      0.02%
#
# [2408 rows x 5 columns]

# %%
group_data['Quantity'].sum()
# Out:
# 5702
